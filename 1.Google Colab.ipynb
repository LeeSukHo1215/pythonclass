# %% [markdown]
# # Google Colaboratory

# %% [markdown]
# ---

# %% [markdown]
# ## Google Colab 특징

# %% [markdown]
# *   구글 클라우드 기반의 무료 개발 환경 서비스
# *   환경 설정 및 실행까지 매우 빠른 환경
# *   딥러닝 실행이 가능한 정도의 고사양 환경 제공
# *   Jypyter Notebook 환경 제공
# *   대부분의 패키지들이 이미 설치된 환경 제공
# *   여러 사용자와 동시에 사용 가능
# *   PC, 태블릿, 모바일 상관없이 인터넷 브라우저만 있으면 어디서나 접속 가능
#
# *   목차나 Markdown 미리보기 등 다양한 기능 제공
# *   구글 드라이브와 연동이 가능
# *   Git이나 Github와 쉽게 연동 가능
#
#
# ### Ipython 정의
#
# - Ipython의 2001년 페르난도 페레즈가 커맨드 라인 인터페이스(CLI)로 개발
#
# - Ipython의 I는 Interactive를 의미, 대화형 방식의 분석 및 개발을 목적으로 만듬
#
# - Ipython은 대화형 노트북을 2011년도에 발표, 노트북은 Mathematica같은 상업 소프트웨어의 영향을 받아서 코드, 텍스트, 수학식, 도표, 그래프, 대화형 그래픽 콘트롤러 등을 웹 브라우저 환경에서 실행되게 만든 웹 인터페이스를 제공
#
# - Ipython은 주피터 노트북의 파이썬 커널 이름
#
# - Ipython만의 기능을 가지고 있음 e.g) 매직명령어 : 여러 가지 특수한 명령어를 가지고 있고, 이를 통해서 동작을 쉽게 제어 가능</br>
#
#
# `커널`이란</br>
# Jupyter에서는 프로그래밍 언어의 실행환경을 kernel이라고 부른다.

# %% [markdown]
# ## Google Colab 주의사항

# %% [markdown]
# *   구글 계정 필요
# *   최대 세션 유지 시간이 존재(12시간)
# *   세션이 종료되면 작업중이던 데이터는 모두 삭제
# *   소스 코드는 구글 드라이브에 저장

# %% [markdown]
# ###REPL(Read–Eval–Print Loop) 방식
#
#
# REPL(Read–Eval–Print Loop, ‘레플’이라고 읽는다) 방식은 주피터 노트북이나 파이썬(또는 IPython) 콘솔을 실행해서 명령어를 한 줄씩 입력하며 실행 상황을 지켜보는 방식이다. 파이썬 프로그래밍을 공부하거나 코드의 초기 버전을 제작할 때 유용한 방식.
# * Deep Learning Model을 training할 때 유용함

# %%
x = 3
x
y = 4
print(x)
print(y)
# Out:
# 3
# 4

# %% [markdown]
# ###Representation
#
# 위의 코드에서 두 번째 명령으로 나오는
# x는 변수 x 값을 표시하라는 뜻이다. 이때 출력되는 것을 그 값의 표현(representation)이라고 한다. 변수 이름을 입력했을 때 표현이 나오는 것은 REPL에서만 가능하고 이후에 설명할 스크립트(*.py) 실행시에는 표시되지 않는다.
#
# 이 방식이 REPL이라고 불리우는 것은 이렇게 명령을 하나 하나 입력하고 실행하면서 변수의 값을 출력하여 살펴보는 것을 반복하면서 코드를 만들기 때문이다.
#
# 물론 위 명령을 셀 하나에 넣고 한꺼번에 실행할 수도 있다. 다만 변수 이름을 지정해서 변수값을 살펴보는 것은 셀의 마지막 line에서만 가능하다.

# %% [markdown]
# ## Google Colab 사양

# %% [markdown]
# * 플랫폼

# %%
import platform 
platform.platform()
# Out:
# 'Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic'

# %% [markdown]
# * 운영체제

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %% [markdown]
# * CPU 사양

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.210
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa
# bogomips	: 4400.42
# clflush size	: 64
# ...

# %% [markdown]
# * 메모리 사양

# %%
! cat /proc/meminfo
# Out:
# MemTotal:       13298580 kB
# MemFree:        10709092 kB
# MemAvailable:   12468576 kB
# Buffers:          110880 kB
# Cached:          1785804 kB
# SwapCached:            0 kB
# Active:          1061444 kB
# Inactive:        1344416 kB
# Active(anon):     447104 kB
# Inactive(anon):      448 kB
# Active(file):     614340 kB
# Inactive(file):  1343968 kB
# Unevictable:           0 kB
# Mlocked:               0 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               476 kB
# Writeback:             0 kB
# AnonPages:        509288 kB
# Mapped:           232248 kB
# Shmem:              1200 kB
# KReclaimable:      85256 kB
# Slab:             128108 kB
# SReclaimable:      85256 kB
# SUnreclaim:        42852 kB
# KernelStack:        4768 kB
# PageTables:         7624 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6649288 kB
# Committed_AS:    3053624 kB
# VmallocTotal:   34359738367 kB
# ...

# %% [markdown]
# * 디스크 사양

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         108G   39G   70G  36% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.8G     0  5.8G   0% /dev/shm
# /dev/root       2.0G  1.2G  812M  59% /sbin/docker-init
# tmpfs           6.4G   36K  6.4G   1% /var/colab
# /dev/sda1        81G   43G   39G  53% /etc/hosts
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %% [markdown]
# * 파이썬 버전

# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# ## Google Colab 런타임
# * Colab에서 고성능 하드웨어로 GPU나 TPU 사용 가능
# * 런타임 유형 변경(Change runtime type) 필요
#   + None: CPU만 사용
#   + GPU: 하드웨어 가속으로 GPU 사용
#   + TPU: 하드웨어 가속으로 TPU 사용

# %%
# !nvidia-smi
# Out:
# Wed Jul 13 02:06:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ## 파일 저장 및 다운로드/업로드
#
# * Jupyter Notebook 환경에서 파일 저장 및 다운로드

# %% [markdown]
# 아래 %%writefile은 매직 명령어임. 구글 코랩 런타임이 구동되고 있는 구글 클라우드
# 인스턴스 객체의 특정 폴더에 위치한 파일에 write 작업을 실행함.

# %%
! pwd
! ls -al
# Out:
# /content
# total 16
# drwxr-xr-x 1 root root 4096 Jul  6 13:22 .
# drwxr-xr-x 1 root root 4096 Jul 13 02:03 ..
# drwxr-xr-x 4 root root 4096 Jul  6 13:21 .config
# drwxr-xr-x 1 root root 4096 Jul  6 13:22 sample_data

# %%
# %%writefile helloworld.txt
# hello world
# Out:
# Writing helloworld.txt

# %%
# !cat helloworld.txt
# Out:
# hello world

# %%
# !touch meto.txt

# %%
ls -al
# Out:
# total 1996
# drwxr-xr-x 1 root root    4096 Jul 13 02:11 ./
# drwxr-xr-x 1 root root    4096 Jul 13 02:03 ../
# -rw-r--r-- 1 root root 2020218 Jul 13 02:08 C4_W4.pdf
# drwxr-xr-x 4 root root    4096 Jul  6 13:21 .config/
# -rw-r--r-- 1 root root      11 Jul 13 02:10 helloworld.txt
# -rw-r--r-- 1 root root       0 Jul 13 02:11 meto.txt
# drwxr-xr-x 1 root root    4096 Jul  6 13:22 sample_data/

# %%
# !cat ./helloworld.txt > ./meto.txt

# %%
# !cat ./meto.txt
# Out:
# hello world

# %% [markdown]
# 위에서 구글 코랩에 생성한 helloworld.txt 파일을 다음과 같이 로컬 PC에 다운로드할 수 있다

# %%
from google.colab import files
files.download('helloworld.txt')

# %% [markdown]
# 로컬 PC의 파일을 구글 코랩에 업로드할 수 있다.

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-bdd4884b-ced4-4647-b5bc-217755af7e9a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdd4884b-ced4-4647-b5bc-217755af7e9a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Untitled.ipynb to Untitled.ipynb

# %%
# !cat helloworld.txt
# Out:
# hello world

# %%
# !pwd
# Out:
# /content

# %%
# !cd /

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# C4_W4.pdf  helloworld.txt  meto.txt  sample_data  Untitled.ipynb

# %% [markdown]
# ## Google Drive 연동
#
# * Google Colab은 Google Drive와 `mount`를 통해 쉽게 연동 가능
# * Google Drive에 소스 코드 저장 뿐만 아니라 파일을 열거나 저장 가능

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/
# Out:
# MyDrive

# %%
# !ls -al /content/drive/MyDrive/
# Out:
# total 12
# drwx------ 2 root root 4096 Feb 14 23:49  학생관리
# drwx------ 2 root root 4096 Feb 15 02:16  교육관련
# drwx------ 2 root root 4096 Feb 15 04:52 'Colab Notebooks'

# %% [markdown]
# ---

# %% [markdown]
# ## help()
#
# * 파이썬 객체에 대한 요약 정보와 사용법 보기

# %%
help(min)
# Out:
# Help on built-in function min in module builtins:
#
# min(...)
#     min(iterable, *[, default=obj, key=func]) -> value
#     min(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its smallest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the smallest argument.

# %% [markdown]
# ## ?로 설명 보기
#
# * 객체 요약 정보 및 사용법이 있는 docstring 보기
#
# *모든 파이썬 객체는 객체에 대한 간결한 요약 정보와 사용법이 담겨 있는 독스트링이라는 문자열에 대한 참조를 포함하고 있다.

# %%
max?

# %%
li = ['one', 'two', 'three']
li?

# %%
li.count?

# %% [markdown]
# Docstring을 설정하기 위해 다음과 같이 """독스트링 내용""" 세 개의 더블쿼테이션으로 독스트링 내용을 감싸면 됨.

# %%
def power(b, n):
  """b의 n승을 리턴"""
  return pow(b, n)

# %%
power?

# %% [markdown]
# ?? 두개를 사용해서 사용자 정의 함수의 소스 코드까지 확인할 수 있다.

# %%
power??

# %% [markdown]
# ## 탭(tab) 자동완성
#
# * 객체와 모듈, 인터페이스의 내용을 자동 완성

# %%
li = ['one', 'two', 'three']
print(li.count)
# Out:
# <built-in method count of list object at 0x7fb9e5c6f0f0>

# %%
li2 = ['one', 'two', 'three']
print(li2.append)

# %% [markdown]
# ##와일드카드(wildcard) 매칭
#
# * 단어의 중간이나 마지막 글자로 매칭하여 객체나 속성 찾기

# %%
*Error?

# %%
str.*index*?

# %%
str.rindex?

# %%
type(str)
# Out:
# type

# %% [markdown]
# ## 매직 명령어(magic commands)
#
# * Jupyter Notebook 환경에서 파이썬 파일 저장 및 실행

# %%
# %%writefile test.py
print('hello colab')
# Out:
# Writing test.py

# %%
# %run test.py
# Out:
# hello colab

# %% [markdown]
# * 코드 실행 시간 측정

# %%
# %%timeit?

# %%
# %timeit li = [n ** n for n in range(10000)]
# Out:
# 1 loop, best of 5: 6.68 s per loop

# %%
# %%timeit
lx = []
for n in range(100):
  lx.append(n**n)
# Out:
# The slowest run took 4.53 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 5: 52.3 µs per loop

# %% [markdown]
# ## 입력과 출력 이력
#
# * In과 Out 객체를 통해 이전 명령어와 명령어의 출력 결과 보기

# %%
In

# %%
Out

# %% [markdown]
# * `_`를 이용해 이전 출력값 출력하기

# %%
print(_)
# Out:
# ['', 'x = 3\nx', 'x = 3\nx\ny = 4\ny', 'x = 3\nx\ny = 4\nx, y', 'x = 3\nx\ny = 4\nprint(x)\nprint(y)', 'import platform \nplatform.platform()', "get_ipython().system('cat /etc/issue.net')", "get_ipython().system('cat /etc/issue.net')", "get_ipython().system('cat /proc/cpuinfo')", "get_ipython().system('cat /proc/meminfo')", "get_ipython().system('df -h ')", "get_ipython().system('python --version')", "get_ipython().system('nvidia-smi')", "get_ipython().system('pwd')\nget_ipython().system('ls -al')", "get_ipython().magic('writefile helloworld.txt  # %% : Magic Command')\nget_ipython().magic('hello world')", "get_ipython().run_cell_magic('writefile', 'helloworld.txt  # %% : Magic Command', 'hello world')", "get_ipython().run_cell_magic('', 'writefile helloworld.txt  # %% : Magic Command', 'hello world')", "get_ipython().run_cell_magic('writefile', 'helloworld.txt  # %% : Magic Command', 'hello world')", 'import platform \nplatform.platform()', "get_ipython().run_cell_magic('writefile',
# ...

# %%
print(__)
# Out:
# <class 'type'>

# %% [markdown]
# * `%history`를 이용한 입력 이력 살펴보기

# %%
# %history -n 1-7
# Out:
#    1:
# from google.colab import drive
# drive.mount('/content/drive')
#    2: !ls /content/drive/
#    3: !ls -al /content/drive/MyDrive/
#    4: help(min)
#    5: max?
#    6:
# li = ['one', 'two', 'three']
# li?
#    7: li.count?

# %% [markdown]
# * `%rerun`을 이용해 이전 입력 이력 다시 실행

# %%
# %rerun

# %% [markdown]
# ## 셸 명령어
#
# * 텍스트 기반의 셸 명령어 처리
# * `!` 문자를 명령어 앞에 붙여서 셸 명령어 사용 가능

# %% [markdown]
# * `ls`: 디렉토리 리스트 보기

# %%
# !ls -al

# %% [markdown]
# * `pwd`: 현재 경로 보기

# %%
# !pwd

# %% [markdown]
# * `cd`: 디렉토리 변경
# * IPython에서는 임시 셸에서 실행

# %%
# !cd sample_data/ && ls

# %% [markdown]
# * `%cd`: 지속적인 디렉토리 변경

# %%
# !pwd
# Out:
# /content

# %%
# %cd sample_data/
# Out:
# /content/sample_data

# %%
# !pwd
# Out:
# /content/sample_data

# %% [markdown]
# * `echo`: 화면 출력

# %%
# !echo "Shell" >> helloworld.txt

# %%
# !cat ./helloworld.txt
# Out:
# hello worldShell

# %% [markdown]
# * `mkdir`: 디렉토리 생성

# %%
# !pwd

# %%
# !ls

# %%
# !mkdir tmp2

# %%
# !ls

# %% [markdown]
# * `cat`: 파일 보기

# %%
# !cat README.md

# %% [markdown]
# * `cp`: 디렉토리/파일 복사

# %%
# !cp README.md tmp2/

# %%
# !ls ./tmp2/

# %% [markdown]
# * `rm`: 디렉토리/파일 삭제

# %%
# !rm -r ./tmp2/

# %%
# !ls

# %% [markdown]
# ---

# %% [markdown]
# # 마크다운(Markdown) 언어
#
# * 문법이 간단하고, 사용이 쉬움

# %% [markdown]
# ## 제목(Heading) 표시

# %% [markdown]
# # Heading 1
# ## Heading 2
# ### Heading 3
# #### Heading 4
# ##### Heading 5
# ###### Heading 6

# %% [markdown]
# ## 목록(List) 구성

# %% [markdown]
# 1.   첫째
# 2.   둘째
# 3.   셋째
#
#
# *   1단계

# %% [markdown]
# ## 폰트 스타일(Font Style)

# %% [markdown]
# **bold**
# __bold__
# *italic*
# _italic_
# ~~strike~~
# <u>underbar</u>

# %% [markdown]
# ## 인용구

# %% [markdown]
# > 인용 1
# >> 인용 2
# >>> 인용 3

# %% [markdown]
# ## 링크

# %% [markdown]
# [Google](https://www.google.com)

# %% [markdown]
# ## 이미지

# %% [markdown]
# ![이미지 1.png](data:image/png;base64,...)

# %% [markdown]
# ## 수평선

# %% [markdown]
# ---

# %% [markdown]
# ## 표

# %% [markdown]
# | C1 | C2 | C3  |
# |:---|---:|:---:|
# | D1 | D2 | D3 |

# %% [markdown]
# ## 코드

# %% [markdown]
# `inline code`
#
# ```python
# def power(b, n)
#   return pow(b, n)
# ```

# %% [markdown]
# [마크다운 가이드](https://colab.research.google.com/notebooks/markdown_guide.ipynb#scrollTo=w86a4I4fmkvD)

# %% [markdown]
# <font color="red">hello world</font>

# %% [markdown]
# * 지수승 : ^
# *[markup:<sup></sup>] x<sup>2</sup>
# * 아래첨자 : _

# %% [markdown]
# * 1.$a^{[7]\lbrace 3 \rbrace (4)}$
# * 2.$a^{[3]\lbrace 7 \rbrace (4)}$
# * 3.$a^{[4]\lbrace 3 \rbrace (7)}$

# %% [markdown]
# Suppose the temperature in Casablanca over the first two days of March are the following:
# March 1st: $\theta_1 = 10^{\circ} \text{ C }θ1=10∘C$
#
# March 2nd: $\theta_2 = 25^{\circ} \text{ C }θ2=25∘C$
#
# Say you use an exponentially weighted average with $\beta = 0.5$ to track the temperature: $v0 = 0$,$vt =βvt−1 + (1−β)θt$
#
# If $v_2$ is the value computed after day 2 without bias correction, and
#
# $v_2^{\text{corrected}}$ is the value you compute with bias correction. What are these values?

# %% [markdown]
# * 1.$v_2 = 15, v_2^{\text{corrected}} = 20$
# * 2.$v_2 = 20, v_2^{\text{corrected}} = 15$
# * 3.$v_2 = 15, v_2^{\text{corrected}} = 15$
# * 4.$v_2 = 20, v_2^{\text{corrected}} = 20$

# %% [markdown]
# * 1.$\alpha = \frac{\alpha_0}{\sqrt{1 + t}}$
# * 2.​$\alpha = \frac{\alpha_0}{{1 + 3t}}$
# * 3.$\alpha = e^{-0.01\, t}\alpha_0$
# * 4.$\alpha = 1.01^{t} \, \alpha_0$

# %% [markdown]
# $v^{t} = \beta v_{t-1} + (1-\beta)\theta_t$ The yellow and red lines were computed using values $\beta$<sub>1</sub> and $\beta$<sub>2</sub> respectively. Which of the following are true?

# %% [markdown]
# * 1.$\beta$<sub>1</sub> > $\beta$<sub>2</sub>
# * 2.$\beta$<sub>1</sub> < $\beta$<sub>2</sub>
# * 3.$\beta$<sub>1</sub> = 0, $\beta$<sub>2</sub> > 0
# * 4.$\beta$<sub>1</sub> = $\beta$<sub>2</sub>

# %% [markdown]
# * $True$
# * $False$

# %% [markdown]
# 1) $(m, n^{[l+1]} )$
#
# 2) $(n^{[l+1]}, m) $
#
# 3) $(n^{[l]}, m) $
#
# 4) $(m, n^{[l]})$

# %% [markdown]
# $B_{(3,3)} =
#  \begin{pmatrix}
#   b_{11} & b_{12} & b_{13} \\
#   b_{21} & b_{22} & b_{23} \\
#   b_{31} & b_{32} & b_{33}
#  \end{pmatrix}$
